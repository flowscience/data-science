# %%
pip install pyTelegramBotAPI
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyTelegramBotAPI: filename=pyTelegramBotAPI-4.12.0-py3-none-any.whl size=213956 sha256=30faea97f1a8d88fd66b78d907b44693b0868d436a3690fe614ccf7f4281dcc0
#   Stored in directory: /root/.cache/pip/wheels/7e/ba/82/f3ab5bc48525778633bccc741c0424677ed3435736221819f4
# Successfully built pyTelegramBotAPI
# ...

# %%
export BOT_TOKEN="123"
source .env
# Out:
#   File "<ipython-input-3-8331bda77991>", line 1
#     export BOT_TOKEN="123"
#            ^
# SyntaxError: invalid syntax
